# %%
#Variant 3 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('books.csv')

# %%
df
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher
# 0    signal_processing     228          Wiley
# 1         data_science     235          Wiley
# ...

# %%
import re

df['Vowel Count'] = df['Author'].str.split(', ').str.get(-1).str.count('(?i)[aeiouy]')
df
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  Vowel Count
# 0    signal_processing     228          Wiley          4.0
# ...

# %%
df[df['Author'].str.split(',').str.get(0).str.contains('[aeiouy]{3}', na=False)]
# Out:
#                                     Title         Author       Genre  \
# 72                                 Scoop!  Nayar, Kuldip  nonfiction
# 75  Social Choice & Welfare, Vol 39 No. 1        Various        tech
#
#      SubGenre  Height      Publisher  Vowel Count
# 72    history     216  HarperCollins          2.0
# 75  economics     235       Springer          4.0

# %%
df['Has number'] = df['Title'].str.contains(r'[0-9]').apply(lambda x: 1 if x else 0)
df.iloc()[160:170]
# Out:
#                                              Title              Author  \
# 160                    Statistical Learning Theory    Vapnik, Vladimir
# 161      Empire of the Mughal - The Tainted Throne    Rutherford, Alex
# 162         Empire of the Mughal - Brothers at War    Rutherford, Alex
# 163      Empire of the Mughal - Ruler of the World    Rutherford, Alex
# 164     Empire of the Mughal - The Serpent's Tooth    Rutherford, Alex
# 165  Empire of the Mughal - Raiders from the North    Rutherford, Alex
# 166                                         Mossad  Baz-Zohar, Michael
# 167                            Jim Corbett Omnibus        Corbett, Jim
# 168                    20000 Leagues Under the Sea        Verne, Jules
# 169                                Batatyachi Chal       Deshpande P L
#
#           Genre      SubGenre  Height Publisher  Vowel Count  Has number
# 160        tech  data_science     228       NaN          3.0           0
# ...

# %%
df[df['Title'].str.len() == df['Title'].str.len().max()]
# Out:
#                                                  Title              Author  \
# 115  Clash of Civilizations and Remaking of the Wor...  Huntington, Samuel
#
#           Genre SubGenre  Height       Publisher  Vowel Count  Has number
# 115  nonfiction  history     228  Simon&Schuster          3.0           0

# %%
df[df['Author'].str.split(', ').str.get(-1).str.startswith('A', na=False)]
# Out:
#                                              Title               Author  \
# 14                               Age of Wrath, The       Eraly, Abraham
# 20                                 Making Software           Oram, Andy
# 27                                   Outsider, The        Camus, Albert
# 28           Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan
# 29          Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan
# 30                          Wealth of Nations, The          Smith, Adam
# 32                                      Mein Kampf        Hitler, Adolf
# 39                         Return of the Primitive            Rand, Ayn
# 56                     Textbook of Economic Theory      Stonier, Alfred
# 59                   Data Structures Using C & C++    Tanenbaum, Andrew
# 66                       Argumentative Indian, The         Sen, Amartya
# 67                                  Sea of Poppies        Ghosh, Amitav
# ...

# %%
df[df['Publisher'].str.split().str.len() == 2]
# Out:
#                                                Title               Author  \
# 6                   Integration of the Indian States           Menon, V P
# 11                               Slaughterhouse Five       Vonnegut, Kurt
# 12                                Birth of a Theorem      Villani, Cedric
# 13   Structure & Interpretation of Computer Programs      Sussman, Gerald
# 15                                        Trial, The         Kafka, Frank
# 16                      Statistical Decision Theory'          Pratt, John
# 25                        Introduction to Algorithms       Cormen, Thomas
# 28             Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan
# 29            Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan
# 30                            Wealth of Nations, The          Smith, Adam
# 31                         Pillars of the Earth, The         Follett, Ken
# 34                   Surely You're Joking Mr Feynman     Feynman, Richard
# ...

# %%
df[df['Author'].str.get(2) == 'y']
# Out:
#                                       Title               Author       Genre  \
# 28    Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan     fiction
# 29   Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan     fiction
# 34          Surely You're Joking Mr Feynman     Feynman, Richard     science
# 72                                   Scoop!        Nayar, Kuldip  nonfiction
# 157                         Neural Networks        Haykin, Simon        tech
# 173           Cathedral and the Bazaar, The        Raymond, Eric        tech
#
#              SubGenre  Height      Publisher  Vowel Count  Has number
# 28            classic     176   Random House          4.0           0
# 29            classic     176   Random House          4.0           0
# 34            physics     198   Random House          2.0           0
# 72            history     216  HarperCollins          2.0           0
# 157      data_science     240            NaN          2.0           0
# ...
